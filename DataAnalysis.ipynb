# %%
import pandas as pd

# %%
df = pd.read_csv("Products.csv")
df
# Out:
#     ProductID                 Name         Category  Price  Quantity
# 0           1            iPhone 12      Electronics   $999        10
# 1           2   Samsung Galaxy S21      Electronics   $899        15
# 2           3          MacBook Pro      Electronics   1999         5
# 3           4          Dell XPS 15          Laptops  $1499         8
# 4           5        PlayStation 5  Gaming Consoles    499        20
# ..        ...                  ...              ...    ...       ...
# 95         96        Apple AirPods        Earphones   $159        15
# 96         97  Samsung Galaxy Buds        Earphones   $129        20
# 97         98       LG NanoCell TV      Televisions   1299         4
# 98         99        Sony X950H TV      Televisions   1799         6
# 99        100          Amazon Echo   Smart Speakers     99        25
#
# [100 rows x 5 columns]

# %%
df["Price"] = df["Price"].str.replace('$','')
df
# Out:
#     ProductID                 Name         Category Price  Quantity
# 0           1            iPhone 12      Electronics   999        10
# 1           2   Samsung Galaxy S21      Electronics   899        15
# 2           3          MacBook Pro      Electronics  1999         5
# 3           4          Dell XPS 15          Laptops  1499         8
# 4           5        PlayStation 5  Gaming Consoles   499        20
# ..        ...                  ...              ...   ...       ...
# 95         96        Apple AirPods        Earphones   159        15
# 96         97  Samsung Galaxy Buds        Earphones   129        20
# 97         98       LG NanoCell TV      Televisions  1299         4
# 98         99        Sony X950H TV      Televisions  1799         6
# 99        100          Amazon Echo   Smart Speakers    99        25
#
# [100 rows x 5 columns]

# %%
# Calculate product revenue
df['Total Sales'] = df['Price'] * df['Quantity']

# Print out DataFrame with calculated Total Sales column
df
# Out:
#     ProductID                 Name         Category Price  Quantity  \
# 0           1            iPhone 12      Electronics   999        10
# 1           2   Samsung Galaxy S21      Electronics   899        15
# 2           3          MacBook Pro      Electronics  1999         5
# 3           4          Dell XPS 15          Laptops  1499         8
# 4           5        PlayStation 5  Gaming Consoles   499        20
# ..        ...                  ...              ...   ...       ...
# 95         96        Apple AirPods        Earphones   159        15
# 96         97  Samsung Galaxy Buds        Earphones   129        20
# 97         98       LG NanoCell TV      Televisions  1299         4
# 98         99        Sony X950H TV      Televisions  1799         6
# 99        100          Amazon Echo   Smart Speakers    99        25
#
#                                           Total Sales
# 0                      999999999999999999999999999999
# ...
